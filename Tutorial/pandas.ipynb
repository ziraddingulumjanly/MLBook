# %% [markdown]
# # Pandas Practice Questions

# %% [markdown]
# [Updated!]
# Pandas is an open-source Python library used for data analysis and manipulation. Developed by Wes McKinney in 2008, it has become a cornerstone of the Python data science ecosystem.
#
# Website - https://pandas.pydata.org/
#
#
# Just remember the two main building blocks:
# Series: A single column.
# DataFrame: The whole table.
#
# # Pandas practice questions
#
# ## 1) Creating Series and DataFrames
#
# 1. Create a `Series` from `[10, 20, 30, 40]`
# ```python
# import pandas as pd
# s = pd.Series([10, 20, 30, 40])
# ```
# 2. recreate a Series that tracks the number of goals scored by three soccer players—Messi, Ronaldo, and Neymar—using their names as the custom index.
#
# import pandas as pd
# goals = [800,900,700]
# players = ["Messi","Ronaldo", "Neymar"]
#
# stats = pd.Series(goals, index = players)
#
# output:
# Messi      800
# Ronaldo    850
# Neymar     400
# dtype: int64
#
# 3. Create a DataFrame with one column `age = [20, 21, 22]`
# import pandas as pd
# age = [20, 21, 22]
# df = pd.DataFrame(age)
# 4. Create a DataFrame with columns:
#
#    * `name = ["Ali", "Leyla", "Murad"]`
#    * `age = [20, 21, 22]`
# ```python
# import pandas as pd
# df = pd.DataFrame({
#     'name' : ["Ali", "Leyla", "Murad"],
#     'age' : [20,21,22]
# })
# print(df)
# ```
#
#
# 5. Create a DataFrame with columns `student`, `score`, `passed`
# ```python
# import pandas as pd
# df = pd.DataFrame({
#     'student' : [John, Steve, Alison],
#     'score' : [90, 98, 57],
#     'passed' : [True, True, False]
# })
# print("DataFrame with columns student, score and passed", df)
# ```
# 6. Create a DataFrame from a dictionary
#
# assume we have below dictionary
# ```python
# # A dictionary representing an inventory of items
# inventory_data = {
#     'item_id': [101, 102, 103, 104],
#     'product': ['Laptop', 'Mouse', 'Monitor', 'Keyboard'],
#     'price': [1200, 25, 300, 75],
#     'in_stock': [True, True, False, True]
# }
# df = pd.DataFrame(inventory_data)
# print(df)
# 7. Create a DataFrame from a list of dictionaries
#
# 8. Create an empty DataFrame
#
# 9. Create a DataFrame and set a custom index
#
# 10. Create a DataFrame with 4 rows and 3 columns of your choice
# - - -
# - - -
# - - -
# - - -
# Name Age Height
# df = pd.DataFrame({
# 'Name' : ["Kate", "Jane", "Jessica"],
# "Age' : [20, 19, 21],
# "Height" : [175, 178, 179]})
# print(df)
#
# ---
#
# ## 2) Reading / basic inspection
#
# 11. Read a CSV file into a DataFrame
# df = pd.read_csv("dataset.csv")
# 12. Show the first 5 rows
# head(n=5): Returns the first n rows of the object. By default, it returns the top 5 rows.
# tail(n=5): Returns the last n rows of the object. By default, it returns the bottom 5 rows
# df.head() # will show 5 rows
# df.head(10) # will show
# 13. Show the last 3 rows
# df.tail(3)
# 14. Check the shape of the DataFrame
# df.shape
# 15. Print the column names
# print(df.columns)
# 16. Check data types of all columns
# df.dyptes
# 17. Get general info about the DataFrame
# df.info()
# 18. Get summary statistics for numeric columns
# df.describe()
# 19. Get summary statistics for all columns
# df.describe(include='all')
# 20. Check how many rows and columns the DataFrame has
#
# Mnemonic:
#
# * `head()` = top
# * `tail()` = bottom
# * `info()` = structure
# * `describe()` = summary
#
# ---
#
# ## 3) Selecting columns
#
# For a DataFrame with columns:
# `name, age, score, city`
#
# 21. Select the `name` column
# x = df['name']
# 22. Select the `score` column
# y = df['score']
# 23. Select two columns: `name` and `score`
# df[['name', 'score']]
#
# 24. Select three columns at once
# df[['name', 'score', 'city']]
#
# 25. Check the type of a single selected column
# type(df['name'])
# 26. Check the type when selecting multiple columns
# type(df[['name', 'score']])
#
# 27. Create a new DataFrame with only `age` and `city`
# new_df = df[['age', 'city']]
#
# Important comparison:
#
# * `df["name"]` → Series
# * `df[["name"]]` → DataFrame
#
# ---
#
# ## 4) Selecting rows
#
# Given a DataFrame with default index:
#
# 28. Select the first row using `.iloc`
# df.iloc[0]
#
# 29. Select the first 3 rows using `.iloc`
# df.iloc[2]
# 30. Select rows 2 to 4 using `.iloc`
# 2, 3, 4
# df.iloc[1,4]
#
# 31. Select the last row using `.iloc`
# df.iloc[-1]
# 32. Select the first row and first two columns
# df.iloc[0,1]
# 33. Select rows by label using `.loc`
# 34. Select multiple labeled rows using `.loc`
# 35. Select a slice of rows using `.loc`
# 36. Select a row and one specific column using `.loc`
# 37. Select rows 0 to 2 and columns `name` and `score`
#
# Mnemonic:
#
# * **iloc** = integer position
# * **loc** = label name
#
# ---
#
# ## 5) Filtering rows
#
# For a DataFrame with columns `name, age, score, city`:
#
# 38. Filter rows where `age > 20`
# arr[arr>20]
# df[df['age']>20]
# 39. Filter rows where `score >= 80`
# df[df['score']>=20]
#
# 40. Filter rows where `city == "Baku"`
# df[df['city']=="Baku"]
#
# 41. Filter rows where `city != "Baku"`
# df[df['city']!="Baku"]
#
# 42. Filter rows where `age > 20 and score > 85`
# df[(df["age"]>20) & (df["score"]>85)]
# filtered_df = df[(df["age"]>20)&(df["score")>85]
# 43. Filter rows where `city is "Baku" or "Ganja"`
# or is denoted as |
# filtered_rows = df[(df["city"]=="Baku")|(df["city"]=="Ganja")]
# for more cities it would be hectical work to do so pandas has .isin method
# filtered_df = df[ df["city"].isin(["Baku","Ganja"])]
#
# 44. Filter rows where score is between 70 and 90
# score < 90 and score > 70
# filtered_score = df[(df["score"]<90)&(df["score"]>70)]
# .between method can be used like we used previously for .isin
# filtered_score = df[df["score"].between(70,90)]
# 45. Filter rows where age is in `[20, 22, 24]`
# filtered_age = df[df["age"].isin(20,22,24)]
#
# 46. Filter rows where name starts with `"A"`
# use str.startswith()
# df[df["name"].str.startswith("A")]
# if you want to include both a and A, it is better to lowercase the A to a and then use startwith
# df[df["name"].str.lower().startswith("A")]
# if dataset has some NaN values then it is better to accept them as False
# df[df["name"].str.lower().startswith("A", na=False)]
#
#
# 47. Filter rows where name contains `"li"`
# use str.contains()
# df[df["name"].str.contains("li",na=False)]
#
# ---
#
# ## 6) Creating and modifying columns
#
# 48. Create a new column `passed` based on score > 50
# df["passed"] = df["score"]>50 this will return True False, if you want specific words for that use np.where()
# df["passed"] = np.where(df["score"]>50, Yes, No)
#
# 49. Create a new column `double_score = score * 2`
# df["double_score"] = df["score"]*2
#
# 50. Create a new column `age_plus_5`
# df["age_plus_5"] = df["age"]+5
# 51. Replace values in a column
# replace can be used
# replaced df = df[column name].reshape(old name, new one)
# df["city"] = df["city"].reshape("London","Manchester")
#
# 52. Rename column `score` to `exam_score`
# Rename changes the header, while Replace changes the actual data.
# # Changes the header of the column
# df = df.rename(columns = {"old_name": "new_name"})
# df = df.replace("Baku","Baku_city")
# 53. Rename multiple columns
# df = df.rename(columns ={
#     "London" : "Liverpool"
#     "Manchester" : "Mancity"
#     "" : ""
# })
# 54. Convert a column to uppercase strings
# lower is used to lowercase
# upper is used to UPPERCASE
# df["city"]  = df["city"].str.upper()
# 55. Create a column from combining two existing columns
# combining can be done with just addition (+)
# df["full_name"] = df["first_name"]+ " " df["last_name"]
# df ["stem_total"] = df["Math"] + " " + df["Physics"]
# 56. Add a constant column with same value in all rows
# df["year"] = 2026
# df["school"] = "Oxford"
# df["school"] = df["Oxford"] WRONG
# This tells pandas: "Go find an existing column named 'Oxford', take all the data inside it, and copy it into a new column called 'school'."
#
# 57. Reorder columns
# # Just list them in the new order
# df = df[["city", "name", "age", "exam_score"]]
#
#
# ---
#
# ## 7) Dropping data
# To "drop" data in pandas, you use the .drop() method. You can drop entire columns or specific rows.
#
# 58. Drop one column
# To get rid of a column you no longer need, specify the name and set axis=1.
# df = df.drop("score",axis=1)
# 59. Drop multiple columns
# df = df.drop(["age","score"],axis=1)
# 60. Drop one row by index
# To remove rows, you usually pass the index number and set axis=0 (which is the default).
# ususally columns have words
# rows have numbers (index)
# lets drop row at the index 7
# df = df.drop(7,axis=0)
#
# 61. Drop multiple rows by index
# like in columns multiple guys should be in brakcets
# lets drop 4,9,10
# df = df.drop([4,9,10], axis=0)
# 62. Drop rows where score < 50
# dropping score < 50 SAME with keeping score >= 50
# df = df[df["score">=50]]
# df[df] --- first df is filter, second is questioning
# df["score">=50] --- question if score is greater than or equal to 50, which returns false true
# df[df["score"]] - filters those true false guys
# 63. Drop rows with missing values
#
# drop + NaN = .dropna()
# axis = 0 rows
# axis = 1 columns
# df = df.dropna(axis=0)
# 64. Drop columns with missing values
# axis = 0 rows
# axis = 1 columns
# dropna(axis=1)
#
# For dropna in some specific columns use subset. To drop rows only when the "score" column is missing, you use the subset parameter. This tells pandas, "Only look at this specific column to make your decision."
# df = df.dropna(subset =["score"])
#
# 65. Drop duplicates
# df =df.drop_dublicate()
# 66. Drop duplicates based on one column only
# df = df.drop_duplicates(subset=["student_id"])
#
# ---
#
# ## 8) Missing values
#
# 67. Check if there are missing values
# 68. Count missing values in each column
# 69. Show rows with at least one missing value
# 70. Fill missing values with 0
# 71. Fill missing values with `"Unknown"`
# 72. Fill missing numeric values with column mean
# 73. Fill missing values forward
# 74. Fill missing values backward
# 75. Check whether a value is null
# 76. Check whether a value is not null
#
# Mnemonic:
#
# * `isnull()` / `isna()` = missing
# * `fillna()` = fill missing
# * `dropna()` = remove missing rows/cols
#
# ---
#
# ## 9) Sorting
# Sorting in pandas uses 2 methods :
# .sort_values() Use .sort_values() to order data by specific columns.
#
#  .sort_index() Use .sort_index() to order by row numbers or column headers.
#
# 77. Sort by `age`
# df.sort_values(by= "age")
# 78. Sort by `score` descending
# df.sort_values(by="score", ascending=False)
# 79. Sort by `city` then `score`
# df = df.sort_values(by=["city", "score"])
# 80. Sort by multiple columns with different ascending rules
# df.sort_values(by=["score","city"] ascending=[True, False])
#
# 81. Reset index after sorting
# df = df.reset_index(drop=True
# 82. Sort index itself
# df = df.sort_index()
#
# ---
#
# ## 10) Aggregation / summaries
#
# For numeric columns:
#
# 83. Find mean of `score`
# df["score"].mean()
# 84. Find max of `score`
# df["score"].max()
#
# 85. Find min of `age`
# df["age"].mix()
#
# 86. Find sum of a numeric column
# df.sum(numeric_only=True)
# 87. Find median of `score`
# df["score"].median()
# 88. Find standard deviation of `score`
# df["score"].std()
# 89. Count non-missing values in each column
#
# 90. Count unique values in `city`
# 91. Find the most frequent value in `city`
# most frequent value is called mode
# df["city"].mode[0]
# 92. Get value counts for `city`
# df["city"].value_counts()
#
# .value_counts() method shows the frequency distribution of your data by listing every unique item in a column alongside the number of times it appears.
# df["fruits"].value_counts(normalize=True)?
#
# ---
#
# ## 11) GroupBy
#
# For a DataFrame with `city, gender, score, age`:
#
# 93. Find mean score by city
# mean score + by city
# df.groupby("city").[["score"]].mean()
# 94. Find max score by city
# df.groupby("city").[["score"]].max()
# 95. Find count of students by city
# 96. Find mean age by gender
# 97. Find mean score by city and gender
# 98. Find multiple aggregations for score by city
# 99. Find min, max, mean together
# 100. Group by one column and summarize another
# 101. Group by two columns and count rows
# 102. Sort grouped results
#
# Mnemonic:
#
# * **groupby** = split into groups
# * then do summary like mean/sum/count
#
#
# ---
#
# ## 12) Unique values / duplicates
# Similiar to the filter on Excel. Used to see unique values in categorical columns and see typose such as London, Londoon
# 103. Find unique cities
# df["city"].unique()
# 104. Count number of unique cities
# to count you need to find the NUMBER of UNIQUE values
# df["city"].nunique()
# 105. Check duplicated rows
# df.dublicated()
# 106. Show only duplicated rows
# df[df.duplicated()]
# 107. Remove duplicated rows
# df.drop_dublicated()
# 108. Remove duplicates based on `name`
# To remove duplicates based only on the "name" column, use the subset parameter within the drop_duplicates() method.
#
# df = df.drop_dublicated(subset = ["name"])
# ---
#
# ## 13) String operations
#
# For a `name` column:
#
# 109. Convert names to lowercase
# df = df["name"].str.lower()
# 110. Convert names to uppercase
# df = df["name"].str.upper()
# 111. Check name lengths
# df["name_length"] = df["name"].str.len()
#
# 112. Find rows where name starts with `"A"`
# df = df[df["name"].str.starts_with("A", na=False)]
# 113. Find rows where name ends with `"a"`
# df = df[df["name"].str.ends_with("A", na=False)]
#
# 114. Find rows where name contains `"li"`
# df =  df[df["name"].str.contains("li", na=False)]
# 115. Replace `"Ali"` with `"ALI"`
# df ["name"]= df["name"].str.replace("Ali", "ALI")
# 116. Split full name into two parts
# # Splits by the space " " and creates two new columns
# df[['first_name', 'last_name']] = df['name'].str.split(' ', expand=True)
#
# ' ': This tells pandas the "separator" is a space. You could use ',' if your data looks like "Doe, John".
# 117. Strip spaces from text column
# [" London "] changes into ["London"]
# df["city"] = df["city"].str.split()
#
# ---
#
# ## 14) Dates
#
# 118. Convert a column to datetime
# df["date"] = pd.to_datetime(df["date"])
# 119. Extract year from a date column
# year month day are extracted using dt.
# df[year]=df["year"].dt.year
# 120. Extract month
# df["month"] = df["date"].dt.month
# 121. Extract day
# df["day"] = df["date"].dt.day
# 122. Filter rows after a certain date
# df["only_2024"] = df[df["date"]> "2023-12-31"]]
# 123. Filter rows between two dates
# filtered_date = df[df["date"].between("2024-01-01","2024-06-31")]
# 124. Sort by date
# df = df.sort_values(by="date")
# df = df.sort_values(by="date", ascending = False)
#
# ---
#
# ## 15) Index work
#
# 126. Set `name` as index
# 127. Reset index
# 128. Select a row by index label
# 129. Select multiple index labels
# 130. Check current index
# 131. Rename index
# 132. Sort by index
#
# ---
#
# ## 16) Apply / map / lambda
# Apply
# Used for: More complex logic. It can work on a single column OR the whole table.
# Best for: Running a function you wrote yourself.
# 133. Use `apply()` on one column
# 134. Use `apply()` to square scores
# # 1. Define your custom rule
# def square_it(number):
#     return number ** 2
# # 2. Tell pandas to use that rule on the score column
# df["score_squared"] = df["score"].apply(square_it)
#
# ORRRRRRRRRRRRRRRRRRRRRR
# use lambda
# # 'x' represents each individual score in the column
# df["score_squared"] = df["score"].apply(lambda x: x**2)
# 135. Use `apply()` with if-else logic
# 136. Use `map()` to replace city names
# 137. Use `applymap()` or element-wise transformation idea on full table
# 138. Create pass/fail labels using lambda
#
# Quick distinction:
#
# * `map()` → usually one Series
# * `apply()` → row/column logic
# * lambda → tiny anonymous function
#
# ---
#
# ## 17) Merging / joining / concatenation
#
# 139. Merge two DataFrames on `student_id`
# 140. Left join two DataFrames
# Take all rows from the left DataFrame (df1), and match what you can from df2.
# pd.merge(df1, df2, on='id', how='left')
# 141. Inner join two DataFrames
# pd.merge(df1, df2, on='id', how='inner')
# Keep only matching rows that exist in both DataFrames.
#
# 142. Outer join two DataFrames
# Keep everything from both DataFrames.
# pd.merge(df1, df2, on='id', how='outer')
#
# 143. Concatenate two DataFrames vertically
# vertically is rowwise so axis has to be 0
# pd.concat([df1, df2], axis=0)
# 144. Concatenate two DataFrames horizontally
# horizontally are columnwise so axis is 1
# pd.concat([df1, df2], axis=0)
# 145. Merge when column names differ in two DataFrames
# 146. Check which rows matched after merge
#
# Mnemonic:
#
# * **merge** = SQL join
# * **concat** = stack or place side by side
#
# ---
#
# ## 18) Value counts / frequency
#
# 147. Count how many times each city appears
# df["city"].value_counts()
# 148. Count normalized proportions of each city
# df["city"].value_counts(normalize=True)
# 149. Count genders
# df["gender"].value_counts()
# 150. Find top 3 most frequent names
#
# df.head()    # Shows first 5 rows
# df.head(10)  # Shows first 10 rows
# .head() is like a "preview" tool.
# so we again use value_counts() with .head()
# top_names = df["name"].value_counts().head(3)
#
# 151. Count combinations of city and gender
# # Shows combinations like (Baku, Male), (Baku, Female), etc.
# counts = df[["city", "gender"]].value_counts()
#
# ---

# %%
# ## 19) Mixed drills

# 152. Create a DataFrame with student names, ages, and scores
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'student' : ["Martha", "Kate", "John"],
    'age' : [19, 26, 22],
    'score' : [90, 80, 85]
})

# 153. Add a new `passed` column where score >= 60
df["passed"]= df[df["score"]>=60]

# 154. Filter only passed students
df[df["passed"] == True]

# 155. Sort students by score descending

# df.sort_values(by='column_name')
df.sort_values(by='student')

# 156. Find average score
df["score"].mean()

# 157. Find highest-scoring student
df["score"].max()

# 158. Find students older than 20 and from Baku
df[df["student"].isin(df["age">20]& df["city"]== "Baku")]
# Simple filtering with two conditions
df[(df["age"] > 20) & (df["city"] == "Baku")]

# 159. Group by city and find average score
# 160. Rename `score` to `exam_score`
# 161. Drop students with missing scores
# 162. Fill missing city values with `"Unknown"`
# 163. Remove duplicate student names
# 164. Select only `name` and `score`
# 165. Set `name` as index, then select one student by label
# 166. Count how many students are in each city
# 167. Find students whose names start with `"A"`
# 168. Create a `score_category` column: low / medium / high
# 169. Merge student table with another table containing department
# 170. Export cleaned DataFrame to CSV

# ---

# ## 20) Real dataset-style question bank

# These are more realistic.

# 171. Read a CSV and inspect first 10 rows
# 172. Check missing values before cleaning
# 173. Remove rows where target column is missing
# 174. Fill numeric missing values with median
# 175. Fill categorical missing values with mode
# 176. Convert a binary text column like `"yes"/"no"` to 1/0
# 177. Encode a category column manually using `map`
# 178. Filter rows where target == 1
# 179. Find class counts of target variable
# 180. Group by category and compare target mean
# 181. Sort by target descending
# 182. Select only numeric columns
# 183. Find correlation-ready subset
# 184. Drop irrelevant ID column
# 185. Create a new feature from old columns
# 186. Detect duplicate IDs
# 187. Keep only rows from certain categories
# 188. Check how many unique values each column has
# 189. Find the top 5 rows by score/value
# 190. Save processed data

# ---

# %% [markdown]
# Dataset below you can use to practice a lot of pandas operations based on the topics in your notes. I made sure it has numeric, categorical, text, dates, missing values, duplicates, booleans, and a few “messy” spots so it feels realistic. It builds well on the areas covered in your practice file.

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "student_id": [101, 102, 103, 104, 105, 106, 107, 108, 109, 110,
                   111, 112, 113, 114, 115, 116, 117, 118, 119, 120],
    
    "name": ["John", "Emma", "Michael", "Sophia", "Daniel", "James", "Olivia", "David", "Isabella", "Ethan",
             "John", "Mia", "Lucas", "Charlotte", "Henry", "Amelia", "Benjamin", "Harper", "Jack", "Grace"],
    
    "age": [20, 21, 22, 20, 23, 24, 21, 22, np.nan, 20,
            20, 23, 25, 22, 21, 24, 23, np.nan, 22, 21],
    
    "city": ["New York", "Chicago", "Boston", "Houston", "Seattle", "New York", "Chicago", None, "Boston", "Miami",
             "New York", "Chicago", "Seattle", "Houston", "Boston", "Chicago", "New York", "Miami", "Seattle", "Boston"],
    
    "gender": ["M", "F", "M", "F", "M", "M", "F", "M", "F", "M",
               "M", "F", "M", "F", "M", "F", "M", "F", "M", "F"],
    
    "score": [88, 76, 91, 65, 59, 72, np.nan, 84, 95, 67,
              88, 73, 54, 81, 60, 77, 69, 92, 58, np.nan],
    
    "attendance": [92, 85, 96, 70, 65, 88, 90, 78, 98, 72,
                   92, 80, 60, 89, 75, 84, 68, 97, 62, 91],
    
    "passed": [True, True, True, True, False, True, True, True, True, True,
               True, True, False, True, True, True, True, True, False, False],
    
    "enrollment_date": ["2024-09-01", "2024-09-03", "2024-09-02", "2024-09-01", "2024-09-05",
                        "2024-09-03", "2024-09-04", "2024-09-02", "2024-09-01", "2024-09-06",
                        "2024-09-01", "2024-09-03", "2024-09-07", "2024-09-02", "2024-09-05",
                        "2024-09-04", "2024-09-06", "2024-09-01", "2024-09-07", "2024-09-03"],
    
    "department": ["Math", "Computer Science", "Physics", "Math", "Biology", "Computer Science", "Physics", "Computer Science", "Math", "Biology",
                   "Math", "Computer Science", "Physics", "Math", "Biology", "Computer Science", "Physics", "Math", "Biology", "Computer Science"]
})

print(df)
